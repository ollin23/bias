# %% [markdown]
# # Pre-Processing for Adult Income Training Data - mk2

# %% [markdown]
# #### 16 May 2022

# %% [markdown]
# ## Import Dependencies

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ### Versions

# %%
print("*** Versions ***")
print("numpy:\t\t", np.__version__)
print("pandas:\t\t", pd.__version__)
# Out:
# *** Versions ***
# numpy:		 1.21.6
# pandas:		 1.4.1

# %% [markdown]
# ## Custom functions

# %% [markdown]
# #### Save to persistent storage

# %%
def custom_save(name, data, kind=1):
    '''
    name : string
        designated filename
    data : data or pytorch model
        the data to save
    kind : int
        sentinel value - 1 if pytorch model, 0 otherwise
    
    custom_save stores the data passed into the function into a file with the provided name
    '''
    
    if kind == 1:
        ex = ".pth"
    else:
        ex = ".parquet"
    
    sentinel = True
    i = 1

    while sentinel:
        dirlist = os.listdir()

        if name not in dirlist:
            if kind == 1:
                torch.save(data, name)
            else:
                data.to_parquet(name)
            print(f"{name} has been saved.")                
            sentinel = False
        if name in dirlist:
            print(f"{name} already exists.", end=" ")
            temp, ext = name.split(ex)
            if "_v" in temp:
                temp, _ = temp.split("_v")
            name = f"{temp}_v{i}{ex}"
            i = i + 1
            print(f"Changing file name to: {name}")

# %% [markdown]
# ### Import & Inspect Data

# %%
features = ['age', 'workclass','fnlwgt','education', 'education-num',
            'marital-status','occupation', 'relationship', 'race', 'sex',
            'capital-gain', 'capital-loss', 'hours-per-week', 'native-country', '50k']

# %% [markdown]
# **Note:** The feature names are not implicitly labelled in the file. They are provided by a metadata file downloaded with the dataset.

# %% [markdown]
# **Note:** *fnlwgt* is a statistical feature added by the US census bureau. It is a multiplicative weight indicating the number of people accounted for by the sample/row

# %%
df = pd.read_csv("adult.test", names=features)
data = df.copy()
data.head()
# Out:
#                     age   workclass    fnlwgt      education  education-num  \
# 0  |1x3 Cross validator         NaN       NaN            NaN            NaN
# 1                    25     Private  226802.0           11th            7.0
# 2                    38     Private   89814.0        HS-grad            9.0
# 3                    28   Local-gov  336951.0     Assoc-acdm           12.0
# 4                    44     Private  160323.0   Some-college           10.0
#
#         marital-status          occupation relationship    race    sex  \
# 0                  NaN                 NaN          NaN     NaN    NaN
# 1        Never-married   Machine-op-inspct    Own-child   Black   Male
# 2   Married-civ-spouse     Farming-fishing      Husband   White   Male
# 3   Married-civ-spouse     Protective-serv      Husband   White   Male
# 4   Married-civ-spouse   Machine-op-inspct      Husband   Black   Male
#
#    capital-gain  capital-loss  hours-per-week  native-country      50k
# ...

# %% [markdown]
# #### Drop first row

# %%
data.drop(0, inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16281 entries, 1 to 16281
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             16281 non-null  object
#  1   workclass       16281 non-null  object
#  2   fnlwgt          16281 non-null  float64
#  3   education       16281 non-null  object
#  4   education-num   16281 non-null  float64
#  5   marital-status  16281 non-null  object
#  6   occupation      16281 non-null  object
#  7   relationship    16281 non-null  object
#  8   race            16281 non-null  object
#  9   sex             16281 non-null  object
#  10  capital-gain    16281 non-null  float64
#  11  capital-loss    16281 non-null  float64
#  12  hours-per-week  16281 non-null  float64
#  13  native-country  16281 non-null  object
#  14  50k             16281 non-null  object
# dtypes: float64(5), object(10)
# memory usage: 1.9+ MB

# %%
data.nunique()
# Out:
# age                  73
# workclass             9
# fnlwgt            12787
# education            16
# education-num        16
# marital-status        7
# occupation           15
# relationship          6
# race                  5
# sex                   2
# capital-gain        113
# capital-loss         82
# hours-per-week       89
# native-country       41
# 50k                   2
# dtype: int64

# %%
data.head(10)
# Out:
#    age          workclass    fnlwgt      education  education-num  \
# 1   25            Private  226802.0           11th            7.0
# 2   38            Private   89814.0        HS-grad            9.0
# 3   28          Local-gov  336951.0     Assoc-acdm           12.0
# 4   44            Private  160323.0   Some-college           10.0
# 5   18                  ?  103497.0   Some-college           10.0
# 6   34            Private  198693.0           10th            6.0
# 7   29                  ?  227026.0        HS-grad            9.0
# 8   63   Self-emp-not-inc  104626.0    Prof-school           15.0
# 9   24            Private  369667.0   Some-college           10.0
# 10  55            Private  104996.0        7th-8th            4.0
#
#          marital-status          occupation    relationship    race      sex  \
# 1         Never-married   Machine-op-inspct       Own-child   Black     Male
# 2    Married-civ-spouse     Farming-fishing         Husband   White     Male
# ...

# %% [markdown]
# #### Inspect Values

# %%
# if the type of column is "object", then display what its values are
for c in data.columns:
    if data[c].dtype == object:
        print(f"{c}: {data[c].dtype}")
        print(data[c].unique())
        print()
# Out:
# age: object
# ['25' '38' '28' '44' '18' '34' '29' '63' '24' '55' '65' '36' '26' '58'
#  '48' '43' '20' '37' '40' '72' '45' '22' '23' '54' '32' '46' '56' '17'
#  '39' '52' '21' '42' '33' '30' '47' '41' '19' '69' '50' '31' '59' '49'
#  '51' '27' '57' '61' '64' '79' '73' '53' '77' '80' '62' '35' '68' '66'
#  '75' '60' '67' '71' '70' '90' '81' '74' '78' '82' '83' '85' '76' '84'
#  '89' '88' '87']
#
# workclass: object
# [' Private' ' Local-gov' ' ?' ' Self-emp-not-inc' ' Federal-gov'
#  ' State-gov' ' Self-emp-inc' ' Without-pay' ' Never-worked']
#
# education: object
# [' 11th' ' HS-grad' ' Assoc-acdm' ' Some-college' ' 10th' ' Prof-school'
#  ' 7th-8th' ' Bachelors' ' Masters' ' Doctorate' ' 5th-6th' ' Assoc-voc'
#  ' 9th' ' 12th' ' 1st-4th' ' Preschool']
#
# marital-status: object
# [' Never-married' ' Married-civ-spouse' ' Widowed' ' Divorced'
#  ' Separated' ' Married-spouse-absent' ' Married-AF-spouse']
#
# occupation: object
# ...

# %% [markdown]
# #### Convert _age_ to integer  values

# %%
data.age = data.age.astype(in)

# %% [markdown]
# #### Convert target values to binary

# %%
target = data["50k"].apply(lambda x: 1 if x==" >50K" else 0)
data = pd.get_dummies(data.drop('50k', axis=1))

# %%
data["target"] = target

# %%
data
# Out:
#        age  fnlwgt  education-num  capital-gain  capital-loss  hours-per-week  \
# 0       39   77516             13          2174             0              40
# 1       50   83311             13             0             0              13
# 2       38  215646              9             0             0              40
# 3       53  234721              7             0             0              40
# 4       28  338409             13             0             0              40
# ...    ...     ...            ...           ...           ...             ...
# 32556   27  257302             12             0             0              38
# 32557   40  154374              9             0             0              40
# 32558   58  151910              9             0             0              40
# 32559   22  201490              9             0             0              20
# 32560   52  287927              9         15024             0              40
#
# ...

# %%
data.shape
# Out:
# (32561, 109)

# %%
data.drop('sex_ Male', axis=1, inplace=True)
data.rename({'sex_ Female': 'gender'}, axis=1, inplace=True)

# %% [markdown]
# ##### Note:
# Under *gender* feature: 1 = female, 0= male

# %%
data.gender.value_counts()
# Out:
# 0    21790
# 1    10771
# Name: gender, dtype: int64

# %%
name = "adult_test_mk2.parquet"
custom_save(name, data, 0)
# Out:
# adult_train_mk2.parquet has been saved.
