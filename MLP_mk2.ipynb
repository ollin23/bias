# %%
import pandas as pd
import numpy as np

# %%
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

import torchmetrics

from torch.utils.data import DataLoader, Dataset
from torch.utils.tensorboard import SummaryWriter

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Build Model

# %% [markdown]
# #### Set Hyperparameters

# %%
# random seed for consistency in pytorch and numpy
SEED = 23

torch.manual_seed(SEED)
np.random.seed(SEED)

# %%
# learning rate
alpha = 0.00001

# %%
# epochs
epochs = 100

# %%
# number of batches
batches = 256

# %%
writer = SummaryWriter("frenchC2Cdata")

# %% [markdown]
# #### Determine device, CPU or GPU

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %% [markdown]
# #### Neural Network

# %%
class MLP(nn.Module):
    
    def __init__(self, in_size):
        super(MLP, self).__init__()

        self.linear_stack = nn.Sequential(
            nn.Linear(in_size, 100),
            nn.ReLU(),
            nn.Linear(100,50),
            nn.ReLU(),
            nn.Linear(50,1),
            nn.Sigmoid()
        )
        
        
    def forward(self, x):
        out = self.linear_stack(x)

        return out

# %%
class MLP_tanh(nn.Module):
    
    def __init__(self, in_size):
        super(MLP_tanh, self).__init__()

        self.linear_stack = nn.Sequential(
            nn.Linear(in_size, 19),
            nn.ReLU(),
            nn.Linear(19,5),
            nn.ReLU(),
            nn.Linear(5,1),
            nn.Tanh()
        )
        
        
    def forward(self, x):
        out = self.linear_stack(x)

        return out

# %% [markdown]
# ## Data

# %% [markdown]
# #### Dataset helper class for PyTorch framework to process tabular data

# %%
class dataset(Dataset):
    def __init__(self, data, target):
        self.X = torch.tensor(data, dtype=torch.float32, device=device)
        self.y = torch.tensor(target, dtype=torch.float32, device=device)
        
    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]
    
    def __len__(self):
        return len(self.X)

# %% [markdown]
# #### Retrieve and check data

# %%
data = pd.read_csv("french_expanded.csv")

# %%
data.shape
# Out:
# (98913, 224)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98913 entries, 0 to 98912
# Columns: 224 entries, socialNbFollowers to language_it
# dtypes: bool(4), float64(2), int64(218)
# memory usage: 166.4 MB

# %% [markdown]
# #### Separate features and target (ie, IV and DV, X and y)

# %%
X = data.drop("target", axis=1).values.astype(np.float32)
y = data.target.values.astype(np.float32)

# %% [markdown]
# #### Split data into train and test. Do not stratify, for baseline

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=SEED)

# %%
training_data = dataset(X_train, y_train)
testing_data = dataset(X_test, y_test)

# %%
training = DataLoader(training_data, batch_size=batches)
testing = DataLoader(testing_data, batch_size=batches)

# %% [markdown]
# ## Train & Test model

# %%
def train(data, model, criterion, metric, optimizer):
    storage_X = []
    storage_y = []
    size = len(data.dataset)
    
    for batch, (X, y_actual) in enumerate(data, 0):
        
        #y_hat = model(X)
        y_hat = model_tanh(X)
        loss = criterion(y_hat, y_actual)
        
        # need to convert y from float to int for accuracy metric
        y = y_actual.int()
        acc = metric(y_hat, y)
        
        #  backprop step
        optimizer.zero_grad() # zero out the gradients
        loss.backward()       # backward pass through model; computes gradients
        optimizer.step()      # update weights
        
        # every 50 batches, store the results
        if batch % 50 == 0:
            storage_X.append(y_hat)
            storage_y.append(y)
            training_loss.append(loss)
            training_accuracy.append(acc)
            current = batch * len(X)
        
            print(f"loss:{loss:1.10f}\taccuracy:{acc:1.10f}\t [{current:6d}/{size:6d}]")
    
    return storage_X, storage_y

# %%
def test(data, model, criterion, metric):
    size = len(data.dataset)
    batches = len(data)
    tst_loss = 0
    correct = 0
    predictions = []
    actuals = []
    
    with torch.no_grad():
        for X, y in data:
            y_hat = model(X)
            y = y.unsqueeze(-1)
            tst_loss += criterion(y_hat, y).item()
            
            y = y.int()
            acc = metric(y_hat, y)
            predictions.append(y_hat)
            actuals.append(y)
            
    tst_loss /= batches
    correct /= size
    
    print(f"Test error:\n\tAccuracy: {acc:0.5f}, Average loss: {tst_loss:10f}\n")
    return predictions, actuals

# %%
def train2(data, model, criterion, metric, optimizer):
    size = len(data.dataset)
    batches = len(data)
    running_loss = []
    acc = 0.0
    correct = 0
    predictions = []
    actuals = []
    
    for batch, (X, y) in enumerate(data,1):
        
        # forward step
        optimizer.zero_grad() # zero out the gradients
        y_hat = model(X)  #forward pass
        
        y = y.unsqueeze(-1) # reduce dimensions of tensor from [256, 1] to [256]
        
        loss = criterion(y_hat, y)  # calculate loss
       
        #  backprop step
        loss.backward()       # backward pass through model; computes gradients
        optimizer.step()      # update weights
        
        # metrics
        y = y.int()
        acc = metric(y_hat, y)

        predictions.append(y_hat)
        actuals.append(y)
            
        running_loss.append(loss.item())
    
        # every 50 batches, store the results
        if batch % size == 0:
            current = batch * len(X)
        
            print(f"loss:{loss:1.10f}\taccuracy:{acc:1.10f}\t [{current:6d}/{size:6d}]")
    
    return predictions, actuals, running_loss

# %%
def scoring2(prediction, actual):
    temp = []

    for el in prediction:
        temp.append(el.cpu().detach().numpy())
    
    prediction = np.array(temp, dtype=object)[0].reshape(-1)
    
    temp = []
    for el in actual:
        temp.append(el.cpu().detach().numpy())
        
    actual = np.array(temp, dtype=object)[0].reshape(-1)

    # create a confusion matrix heatmap
    cm = confusion_matrix(np.round(prediction), actual)
    cm = pd.DataFrame(cm/np.sum(cm),
                      index=["Predicted False", "Predicted True"],
                      columns=["Actual False", "Actual True"])

    return prediction, actual, cm

# %% [markdown]
# # Training Cycle

# %% [markdown]
# #### Construct model

# %%
model = MLP(X_train.shape[1]).to(device)
print(model.named_parameters)
# Out:
# <bound method Module.named_parameters of MLP(
#   (linear_stack): Sequential(
#     (0): Linear(in_features=223, out_features=100, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=100, out_features=50, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=50, out_features=1, bias=True)
#     (5): Sigmoid()
#   )
# )>

# %%
model_tanh = MLP_tanh(X_train.shape[1]).to(device)
print(model_tanh.named_parameters)
# Out:
# <bound method Module.named_parameters of MLP_tanh(
#   (linear_stack): Sequential(
#     (0): Linear(in_features=223, out_features=19, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=19, out_features=5, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=5, out_features=1, bias=True)
#     (5): Tanh()
#   )
# )>

# %% [markdown]
# #### Optimizer and Loss/Criterion Function

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=alpha)
criterion = nn.BCELoss()
accuracy = torchmetrics.functional.accuracy

# %% [markdown]
# #### Train model

# %%
training_loss = []
training_accuracy = []

test_loss = []
test_accuracy = []

trng_predictions = []
test_predictions = []

for epoch in range(1,epochs+1):
    print (f"* * * * * * * * * *\nEpoch {epoch}")
    
    training_result, trng_actual, loss = train2(training, model, criterion, accuracy, optimizer)
    testing_result, test_actual = test(testing, model, criterion, accuracy)

    training_loss.append(loss)
    
print("Finished")
# Out:
# * * * * * * * * * *
# Epoch 1
# loss:0.6294394135	accuracy:0.7695312500	 [ 12800/ 69239]
# loss:0.3769294620	accuracy:0.8632812500	 [ 25600/ 69239]
# loss:0.2742008567	accuracy:0.8984375000	 [ 38400/ 69239]
# loss:0.2475699484	accuracy:0.8945312500	 [ 51200/ 69239]
# loss:0.2085981816	accuracy:0.9140625000	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.90598, Average loss:   0.214432
#
# * * * * * * * * * *
# Epoch 2
# loss:0.2206004560	accuracy:0.9179687500	 [ 12800/ 69239]
# loss:0.1886506528	accuracy:0.9335937500	 [ 25600/ 69239]
# loss:0.1655074358	accuracy:0.9492187500	 [ 38400/ 69239]
# loss:0.2007668465	accuracy:0.9531250000	 [ 51200/ 69239]
# loss:0.1725510657	accuracy:0.9570312500	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.94444, Average loss:   0.185946
#
# * * * * * * * * * *
# Epoch 3
# loss:0.1930462867	accuracy:0.9531250000	 [ 12800/ 69239]
# loss:0.1704328209	accuracy:0.9531250000	 [ 25600/ 69239]
# loss:0.1532394141	accuracy:0.9453125000	 [ 38400/ 69239]
# loss:0.1965747774	accuracy:0.9414062500	 [ 51200/ 69239]
# loss:0.1636972278	accuracy:0.9570312500	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.94444, Average loss:   0.178617
#
# * * * * * * * * * *
# Epoch 4
# loss:0.1806723028	accuracy:0.9570312500	 [ 12800/ 69239]
# loss:0.1627420485	accuracy:0.9570312500	 [ 25600/ 69239]
# loss:0.1505775005	accuracy:0.9453125000	 [ 38400/ 69239]
# loss:0.1954994202	accuracy:0.9414062500	 [ 51200/ 69239]
# loss:0.1596451998	accuracy:0.9531250000	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.94872, Average loss:   0.175050
#
# * * * * * * * * * *
# Epoch 5
# loss:0.1739062369	accuracy:0.9609375000	 [ 12800/ 69239]
# loss:0.1581692547	accuracy:0.9570312500	 [ 25600/ 69239]
# loss:0.1507283300	accuracy:0.9453125000	 [ 38400/ 69239]
# loss:0.1939817369	accuracy:0.9414062500	 [ 51200/ 69239]
# loss:0.1568433642	accuracy:0.9531250000	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.94872, Average loss:   0.172500
#
# * * * * * * * * * *
# Epoch 6
# loss:0.1672116816	accuracy:0.9570312500	 [ 12800/ 69239]
# loss:0.1540054530	accuracy:0.9570312500	 [ 25600/ 69239]
# loss:0.1513265669	accuracy:0.9453125000	 [ 38400/ 69239]
# loss:0.1937987506	accuracy:0.9414062500	 [ 51200/ 69239]
# loss:0.1557753086	accuracy:0.9531250000	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.95299, Average loss:   0.171098
#
# * * * * * * * * * *
# Epoch 7
# loss:0.1636029631	accuracy:0.9570312500	 [ 12800/ 69239]
# loss:0.1522816569	accuracy:0.9570312500	 [ 25600/ 69239]
# loss:0.1523187160	accuracy:0.9492187500	 [ 38400/ 69239]
# loss:0.1937240958	accuracy:0.9453125000	 [ 51200/ 69239]
# loss:0.1550568640	accuracy:0.9531250000	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.95726, Average loss:   0.170211
#
# * * * * * * * * * *
# Epoch 8
# loss:0.1612743735	accuracy:0.9570312500	 [ 12800/ 69239]
# loss:0.1509357393	accuracy:0.9570312500	 [ 25600/ 69239]
# loss:0.1529317498	accuracy:0.9492187500	 [ 38400/ 69239]
# loss:0.1939534843	accuracy:0.9453125000	 [ 51200/ 69239]
# loss:0.1545464098	accuracy:0.9570312500	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.95726, Average loss:   0.169477
#
# * * * * * * * * * *
# Epoch 9
# loss:0.1596637964	accuracy:0.9570312500	 [ 12800/ 69239]
# loss:0.1499402821	accuracy:0.9570312500	 [ 25600/ 69239]
# loss:0.1534227431	accuracy:0.9453125000	 [ 38400/ 69239]
# loss:0.1942775249	accuracy:0.9453125000	 [ 51200/ 69239]
# loss:0.1540259421	accuracy:0.9570312500	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.95726, Average loss:   0.168844
#
# * * * * * * * * * *
# Epoch 10
# loss:0.1583089530	accuracy:0.9570312500	 [ 12800/ 69239]
# loss:0.1490257531	accuracy:0.9570312500	 [ 25600/ 69239]
# loss:0.1537579447	accuracy:0.9453125000	 [ 38400/ 69239]
# loss:0.1945062280	accuracy:0.9453125000	 [ 51200/ 69239]
# loss:0.1535406560	accuracy:0.9570312500	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.95726, Average loss:   0.168268
#
# * * * * * * * * * *
# Epoch 11
# loss:0.1571280658	accuracy:0.9570312500	 [ 12800/ 69239]
# loss:0.1482863575	accuracy:0.9570312500	 [ 25600/ 69239]
# loss:0.1539433300	accuracy:0.9453125000	 [ 38400/ 69239]
# loss:0.1946601421	accuracy:0.9453125000	 [ 51200/ 69239]
# loss:0.1530714333	accuracy:0.9570312500	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.95726, Average loss:   0.167720
#
# * * * * * * * * * *
# Epoch 12
# loss:0.1561293304	accuracy:0.9570312500	 [ 12800/ 69239]
# loss:0.1476441920	accuracy:0.9570312500	 [ 25600/ 69239]
# loss:0.1540012509	accuracy:0.9453125000	 [ 38400/ 69239]
# loss:0.1946164370	accuracy:0.9453125000	 [ 51200/ 69239]
# loss:0.1526282728	accuracy:0.9570312500	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.95726, Average loss:   0.167190
#
# * * * * * * * * * *
# Epoch 13
# loss:0.1553507149	accuracy:0.9570312500	 [ 12800/ 69239]
# loss:0.1470666975	accuracy:0.9570312500	 [ 25600/ 69239]
# loss:0.1540206969	accuracy:0.9453125000	 [ 38400/ 69239]
# loss:0.1946564019	accuracy:0.9414062500	 [ 51200/ 69239]
# loss:0.1521998048	accuracy:0.9570312500	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.95726, Average loss:   0.166662
#
# * * * * * * * * * *
# Epoch 14
# loss:0.1546798944	accuracy:0.9570312500	 [ 12800/ 69239]
# loss:0.1465506554	accuracy:0.9570312500	 [ 25600/ 69239]
# loss:0.1539548934	accuracy:0.9453125000	 [ 38400/ 69239]
# loss:0.1947348565	accuracy:0.9414062500	 [ 51200/ 69239]
# loss:0.1518141329	accuracy:0.9531250000	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.95726, Average loss:   0.166152
#
# * * * * * * * * * *
# Epoch 15
# loss:0.1540274322	accuracy:0.9609375000	 [ 12800/ 69239]
# loss:0.1461247802	accuracy:0.9570312500	 [ 25600/ 69239]
# loss:0.1538043618	accuracy:0.9453125000	 [ 38400/ 69239]
# loss:0.1947282851	accuracy:0.9414062500	 [ 51200/ 69239]
# loss:0.1514306366	accuracy:0.9531250000	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.95726, Average loss:   0.165637
#
# * * * * * * * * * *
# Epoch 16
# loss:0.1534825563	accuracy:0.9609375000	 [ 12800/ 69239]
# loss:0.1457069516	accuracy:0.9570312500	 [ 25600/ 69239]
# loss:0.1536319852	accuracy:0.9453125000	 [ 38400/ 69239]
# loss:0.1946738660	accuracy:0.9414062500	 [ 51200/ 69239]
# loss:0.1510746777	accuracy:0.9531250000	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.95726, Average loss:   0.165122
#
# * * * * * * * * * *
# Epoch 17
# loss:0.1529878825	accuracy:0.9609375000	 [ 12800/ 69239]
# loss:0.1452931464	accuracy:0.9570312500	 [ 25600/ 69239]
# loss:0.1533793807	accuracy:0.9453125000	 [ 38400/ 69239]
# loss:0.1945855319	accuracy:0.9414062500	 [ 51200/ 69239]
# loss:0.1507307887	accuracy:0.9531250000	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.95726, Average loss:   0.164630
#
# * * * * * * * * * *
# Epoch 18
# loss:0.1524437964	accuracy:0.9609375000	 [ 12800/ 69239]
# loss:0.1448922604	accuracy:0.9570312500	 [ 25600/ 69239]
# loss:0.1531056166	accuracy:0.9453125000	 [ 38400/ 69239]
# loss:0.1943998784	accuracy:0.9375000000	 [ 51200/ 69239]
# loss:0.1503493190	accuracy:0.9531250000	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.95726, Average loss:   0.164147
#
# * * * * * * * * * *
# Epoch 19
# loss:0.1519402266	accuracy:0.9609375000	 [ 12800/ 69239]
# loss:0.1445125192	accuracy:0.9609375000	 [ 25600/ 69239]
# loss:0.1527690291	accuracy:0.9453125000	 [ 38400/ 69239]
# loss:0.1942086965	accuracy:0.9375000000	 [ 51200/ 69239]
# loss:0.1500035077	accuracy:0.9531250000	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.95726, Average loss:   0.163670
#
# * * * * * * * * * *
# Epoch 20
# loss:0.1514102072	accuracy:0.9609375000	 [ 12800/ 69239]
# loss:0.1440985650	accuracy:0.9609375000	 [ 25600/ 69239]
# loss:0.1525074840	accuracy:0.9453125000	 [ 38400/ 69239]
# loss:0.1939815730	accuracy:0.9375000000	 [ 51200/ 69239]
# loss:0.1496874839	accuracy:0.9531250000	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.95726, Average loss:   0.163197
#
# * * * * * * * * * *
# Epoch 21
# loss:0.1509264857	accuracy:0.9609375000	 [ 12800/ 69239]
# loss:0.1437332928	accuracy:0.9609375000	 [ 25600/ 69239]
# loss:0.1521282196	accuracy:0.9453125000	 [ 38400/ 69239]
# loss:0.1937041134	accuracy:0.9375000000	 [ 51200/ 69239]
# loss:0.1493443251	accuracy:0.9531250000	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.95726, Average loss:   0.162727
#
# * * * * * * * * * *
# Epoch 22
# loss:0.1504383087	accuracy:0.9609375000	 [ 12800/ 69239]
# loss:0.1434050947	accuracy:0.9609375000	 [ 25600/ 69239]
# loss:0.1517369747	accuracy:0.9453125000	 [ 38400/ 69239]
# loss:0.1933365315	accuracy:0.9375000000	 [ 51200/ 69239]
# loss:0.1489990652	accuracy:0.9531250000	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.95726, Average loss:   0.162247
#
# * * * * * * * * * *
# Epoch 23
# loss:0.1499273926	accuracy:0.9648437500	 [ 12800/ 69239]
# loss:0.1430437863	accuracy:0.9609375000	 [ 25600/ 69239]
# loss:0.1514159292	accuracy:0.9453125000	 [ 38400/ 69239]
# loss:0.1930170208	accuracy:0.9375000000	 [ 51200/ 69239]
# loss:0.1487081498	accuracy:0.9531250000	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.95726, Average loss:   0.161762
#
# * * * * * * * * * *
# Epoch 24
# loss:0.1494494081	accuracy:0.9648437500	 [ 12800/ 69239]
# loss:0.1427440494	accuracy:0.9609375000	 [ 25600/ 69239]
# loss:0.1510269195	accuracy:0.9453125000	 [ 38400/ 69239]
# loss:0.1926331818	accuracy:0.9375000000	 [ 51200/ 69239]
# loss:0.1484057009	accuracy:0.9531250000	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.95726, Average loss:   0.161246
#
# * * * * * * * * * *
# Epoch 25
# loss:0.1489367187	accuracy:0.9648437500	 [ 12800/ 69239]
# loss:0.1424891502	accuracy:0.9609375000	 [ 25600/ 69239]
# loss:0.1506838799	accuracy:0.9453125000	 [ 38400/ 69239]
# loss:0.1922491789	accuracy:0.9375000000	 [ 51200/ 69239]
# loss:0.1482081264	accuracy:0.9531250000	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.95726, Average loss:   0.160747
#
# * * * * * * * * * *
# Epoch 26
# loss:0.1484618038	accuracy:0.9648437500	 [ 12800/ 69239]
# loss:0.1422236860	accuracy:0.9609375000	 [ 25600/ 69239]
# loss:0.1503749341	accuracy:0.9453125000	 [ 38400/ 69239]
# loss:0.1917279959	accuracy:0.9375000000	 [ 51200/ 69239]
# loss:0.1479615271	accuracy:0.9531250000	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.95726, Average loss:   0.160245
#
# * * * * * * * * * *
# Epoch 27
# loss:0.1480566263	accuracy:0.9648437500	 [ 12800/ 69239]
# loss:0.1419893503	accuracy:0.9609375000	 [ 25600/ 69239]
# loss:0.1500732005	accuracy:0.9453125000	 [ 38400/ 69239]
# loss:0.1911196113	accuracy:0.9375000000	 [ 51200/ 69239]
# loss:0.1477183402	accuracy:0.9531250000	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.95726, Average loss:   0.159709
#
# * * * * * * * * * *
# Epoch 28
# loss:0.1477767080	accuracy:0.9648437500	 [ 12800/ 69239]
# loss:0.1418260336	accuracy:0.9609375000	 [ 25600/ 69239]
# loss:0.1499034017	accuracy:0.9414062500	 [ 38400/ 69239]
# loss:0.1904745102	accuracy:0.9375000000	 [ 51200/ 69239]
# loss:0.1475901604	accuracy:0.9570312500	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.95726, Average loss:   0.159171
#
# * * * * * * * * * *
# Epoch 29
# loss:0.1473847032	accuracy:0.9648437500	 [ 12800/ 69239]
# loss:0.1415122449	accuracy:0.9609375000	 [ 25600/ 69239]
# loss:0.1491516083	accuracy:0.9414062500	 [ 38400/ 69239]
# loss:0.1894888878	accuracy:0.9375000000	 [ 51200/ 69239]
# loss:0.1468093097	accuracy:0.9570312500	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.95726, Average loss:   0.158374
#
# * * * * * * * * * *
# Epoch 30
# loss:0.1468805075	accuracy:0.9648437500	 [ 12800/ 69239]
# loss:0.1407779008	accuracy:0.9609375000	 [ 25600/ 69239]
# loss:0.1485265195	accuracy:0.9414062500	 [ 38400/ 69239]
# loss:0.1889534295	accuracy:0.9375000000	 [ 51200/ 69239]
# loss:0.1463510543	accuracy:0.9570312500	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.95726, Average loss:   0.157692
#
# * * * * * * * * * *
# Epoch 31
# loss:0.1460053623	accuracy:0.9648437500	 [ 12800/ 69239]
# loss:0.1401636451	accuracy:0.9609375000	 [ 25600/ 69239]
# loss:0.1479745805	accuracy:0.9414062500	 [ 38400/ 69239]
# loss:0.1885763109	accuracy:0.9375000000	 [ 51200/ 69239]
# loss:0.1459204555	accuracy:0.9570312500	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.95726, Average loss:   0.157094
#
# * * * * * * * * * *
# Epoch 32
# loss:0.1454296112	accuracy:0.9648437500	 [ 12800/ 69239]
# loss:0.1398485005	accuracy:0.9609375000	 [ 25600/ 69239]
# loss:0.1474579722	accuracy:0.9414062500	 [ 38400/ 69239]
# loss:0.1879972517	accuracy:0.9375000000	 [ 51200/ 69239]
# loss:0.1455348134	accuracy:0.9570312500	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.95726, Average loss:   0.156499
#
# * * * * * * * * * *
# Epoch 33
# loss:0.1448813379	accuracy:0.9648437500	 [ 12800/ 69239]
# loss:0.1395208687	accuracy:0.9609375000	 [ 25600/ 69239]
# loss:0.1468986571	accuracy:0.9414062500	 [ 38400/ 69239]
# loss:0.1874356270	accuracy:0.9375000000	 [ 51200/ 69239]
# loss:0.1452478468	accuracy:0.9570312500	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.95726, Average loss:   0.155904
#
# * * * * * * * * * *
# Epoch 34
# loss:0.1443489939	accuracy:0.9648437500	 [ 12800/ 69239]
# loss:0.1392289996	accuracy:0.9570312500	 [ 25600/ 69239]
# loss:0.1463118047	accuracy:0.9414062500	 [ 38400/ 69239]
# loss:0.1868482828	accuracy:0.9375000000	 [ 51200/ 69239]
# loss:0.1450168490	accuracy:0.9570312500	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.95726, Average loss:   0.155235
#
# * * * * * * * * * *
# Epoch 35
# loss:0.1437758207	accuracy:0.9648437500	 [ 12800/ 69239]
# loss:0.1388940364	accuracy:0.9570312500	 [ 25600/ 69239]
# loss:0.1454786956	accuracy:0.9414062500	 [ 38400/ 69239]
# loss:0.1858938932	accuracy:0.9375000000	 [ 51200/ 69239]
# loss:0.1445888281	accuracy:0.9570312500	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.96154, Average loss:   0.154471
#
# * * * * * * * * * *
# Epoch 36
# loss:0.1431734562	accuracy:0.9648437500	 [ 12800/ 69239]
# loss:0.1384928077	accuracy:0.9570312500	 [ 25600/ 69239]
# loss:0.1448161006	accuracy:0.9414062500	 [ 38400/ 69239]
# loss:0.1853261590	accuracy:0.9375000000	 [ 51200/ 69239]
# loss:0.1441782415	accuracy:0.9570312500	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.96154, Average loss:   0.153816
#
# * * * * * * * * * *
# Epoch 37
# loss:0.1426396668	accuracy:0.9648437500	 [ 12800/ 69239]
# loss:0.1381610036	accuracy:0.9570312500	 [ 25600/ 69239]
# loss:0.1441446543	accuracy:0.9414062500	 [ 38400/ 69239]
# loss:0.1846175492	accuracy:0.9375000000	 [ 51200/ 69239]
# loss:0.1437960714	accuracy:0.9570312500	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.96154, Average loss:   0.153163
#
# * * * * * * * * * *
# Epoch 38
# loss:0.1420125067	accuracy:0.9648437500	 [ 12800/ 69239]
# loss:0.1377547979	accuracy:0.9570312500	 [ 25600/ 69239]
# loss:0.1434796005	accuracy:0.9414062500	 [ 38400/ 69239]
# loss:0.1840170622	accuracy:0.9375000000	 [ 51200/ 69239]
# loss:0.1434093416	accuracy:0.9570312500	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.96154, Average loss:   0.152520
#
# * * * * * * * * * *
# Epoch 39
# loss:0.1413815320	accuracy:0.9648437500	 [ 12800/ 69239]
# loss:0.1372942179	accuracy:0.9570312500	 [ 25600/ 69239]
# loss:0.1428136677	accuracy:0.9414062500	 [ 38400/ 69239]
# loss:0.1832002401	accuracy:0.9375000000	 [ 51200/ 69239]
# loss:0.1429502368	accuracy:0.9570312500	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.96154, Average loss:   0.151879
#
# * * * * * * * * * *
# Epoch 40
# loss:0.1407230198	accuracy:0.9648437500	 [ 12800/ 69239]
# loss:0.1369184554	accuracy:0.9570312500	 [ 25600/ 69239]
# loss:0.1421099007	accuracy:0.9414062500	 [ 38400/ 69239]
# loss:0.1825187504	accuracy:0.9375000000	 [ 51200/ 69239]
# loss:0.1425225437	accuracy:0.9570312500	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.96154, Average loss:   0.151215
#
# * * * * * * * * * *
# Epoch 41
# loss:0.1401791871	accuracy:0.9648437500	 [ 12800/ 69239]
# loss:0.1365529299	accuracy:0.9570312500	 [ 25600/ 69239]
# loss:0.1413660794	accuracy:0.9414062500	 [ 38400/ 69239]
# loss:0.1819389760	accuracy:0.9375000000	 [ 51200/ 69239]
# loss:0.1421232969	accuracy:0.9570312500	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.96154, Average loss:   0.150553
#
# * * * * * * * * * *
# Epoch 42
# loss:0.1395310462	accuracy:0.9648437500	 [ 12800/ 69239]
# loss:0.1361635029	accuracy:0.9570312500	 [ 25600/ 69239]
# loss:0.1406062543	accuracy:0.9414062500	 [ 38400/ 69239]
# loss:0.1812118888	accuracy:0.9375000000	 [ 51200/ 69239]
# loss:0.1417115927	accuracy:0.9570312500	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.96154, Average loss:   0.149873
#
# * * * * * * * * * *
# Epoch 43
# loss:0.1388878226	accuracy:0.9687500000	 [ 12800/ 69239]
# loss:0.1358180642	accuracy:0.9570312500	 [ 25600/ 69239]
# loss:0.1398784816	accuracy:0.9414062500	 [ 38400/ 69239]
# loss:0.1804675758	accuracy:0.9375000000	 [ 51200/ 69239]
# loss:0.1412924826	accuracy:0.9570312500	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.96154, Average loss:   0.149181
#
# * * * * * * * * * *
# Epoch 44
# loss:0.1382806599	accuracy:0.9687500000	 [ 12800/ 69239]
# loss:0.1354174465	accuracy:0.9570312500	 [ 25600/ 69239]
# loss:0.1391029060	accuracy:0.9414062500	 [ 38400/ 69239]
# loss:0.1796360314	accuracy:0.9375000000	 [ 51200/ 69239]
# loss:0.1408728063	accuracy:0.9570312500	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.96154, Average loss:   0.148454
#
# * * * * * * * * * *
# Epoch 45
# loss:0.1376843899	accuracy:0.9687500000	 [ 12800/ 69239]
# loss:0.1350668669	accuracy:0.9570312500	 [ 25600/ 69239]
# loss:0.1383922696	accuracy:0.9414062500	 [ 38400/ 69239]
# loss:0.1784634590	accuracy:0.9375000000	 [ 51200/ 69239]
# loss:0.1403859258	accuracy:0.9570312500	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.96154, Average loss:   0.147558
#
# * * * * * * * * * *
# Epoch 46
# loss:0.1369185150	accuracy:0.9687500000	 [ 12800/ 69239]
# loss:0.1345201433	accuracy:0.9570312500	 [ 25600/ 69239]
# loss:0.1374451816	accuracy:0.9414062500	 [ 38400/ 69239]
# loss:0.1775609106	accuracy:0.9375000000	 [ 51200/ 69239]
# loss:0.1399704516	accuracy:0.9570312500	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.95726, Average loss:   0.146703
#
# * * * * * * * * * *
# Epoch 47
# loss:0.1361417472	accuracy:0.9687500000	 [ 12800/ 69239]
# loss:0.1338254213	accuracy:0.9570312500	 [ 25600/ 69239]
# loss:0.1364021897	accuracy:0.9414062500	 [ 38400/ 69239]
# loss:0.1766864657	accuracy:0.9375000000	 [ 51200/ 69239]
# loss:0.1391735375	accuracy:0.9570312500	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.95726, Average loss:   0.145786
#
# * * * * * * * * * *
# Epoch 48
# loss:0.1352042556	accuracy:0.9687500000	 [ 12800/ 69239]
# loss:0.1331722140	accuracy:0.9570312500	 [ 25600/ 69239]
# loss:0.1352373958	accuracy:0.9414062500	 [ 38400/ 69239]
# loss:0.1757310331	accuracy:0.9375000000	 [ 51200/ 69239]
# loss:0.1384693533	accuracy:0.9570312500	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.95726, Average loss:   0.144913
#
# * * * * * * * * * *
# Epoch 49
# loss:0.1344862878	accuracy:0.9687500000	 [ 12800/ 69239]
# loss:0.1324098259	accuracy:0.9570312500	 [ 25600/ 69239]
# loss:0.1334927082	accuracy:0.9414062500	 [ 38400/ 69239]
# loss:0.1735181808	accuracy:0.9375000000	 [ 51200/ 69239]
# loss:0.1370547712	accuracy:0.9570312500	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.95726, Average loss:   0.143158
#
# * * * * * * * * * *
# Epoch 50
# loss:0.1327408850	accuracy:0.9687500000	 [ 12800/ 69239]
# loss:0.1311462820	accuracy:0.9570312500	 [ 25600/ 69239]
# loss:0.1322551966	accuracy:0.9453125000	 [ 38400/ 69239]
# loss:0.1726430357	accuracy:0.9375000000	 [ 51200/ 69239]
# loss:0.1365368217	accuracy:0.9570312500	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.95726, Average loss:   0.142219
#
# * * * * * * * * * *
# Epoch 51
# loss:0.1319254637	accuracy:0.9687500000	 [ 12800/ 69239]
# loss:0.1304550022	accuracy:0.9570312500	 [ 25600/ 69239]
# loss:0.1312638074	accuracy:0.9453125000	 [ 38400/ 69239]
# loss:0.1718426347	accuracy:0.9375000000	 [ 51200/ 69239]
# loss:0.1359692514	accuracy:0.9570312500	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.95726, Average loss:   0.141313
#
# * * * * * * * * * *
# Epoch 52
# loss:0.1311429739	accuracy:0.9687500000	 [ 12800/ 69239]
# loss:0.1297706515	accuracy:0.9570312500	 [ 25600/ 69239]
# loss:0.1303372383	accuracy:0.9453125000	 [ 38400/ 69239]
# loss:0.1708883941	accuracy:0.9375000000	 [ 51200/ 69239]
# loss:0.1354357302	accuracy:0.9570312500	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.95726, Average loss:   0.140427
#
# * * * * * * * * * *
# Epoch 53
# loss:0.1303760707	accuracy:0.9687500000	 [ 12800/ 69239]
# loss:0.1290971935	accuracy:0.9570312500	 [ 25600/ 69239]
# loss:0.1293757111	accuracy:0.9453125000	 [ 38400/ 69239]
# loss:0.1700190455	accuracy:0.9375000000	 [ 51200/ 69239]
# loss:0.1348000914	accuracy:0.9570312500	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.95726, Average loss:   0.139536
#
# * * * * * * * * * *
# Epoch 54
# loss:0.1295151711	accuracy:0.9687500000	 [ 12800/ 69239]
# loss:0.1284701824	accuracy:0.9570312500	 [ 25600/ 69239]
# loss:0.1283463538	accuracy:0.9453125000	 [ 38400/ 69239]
# loss:0.1692321450	accuracy:0.9375000000	 [ 51200/ 69239]
# loss:0.1342402548	accuracy:0.9570312500	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.95726, Average loss:   0.138647
#
# * * * * * * * * * *
# Epoch 55
# loss:0.1287195981	accuracy:0.9687500000	 [ 12800/ 69239]
# loss:0.1278232783	accuracy:0.9570312500	 [ 25600/ 69239]
# loss:0.1273470670	accuracy:0.9453125000	 [ 38400/ 69239]
# loss:0.1682182252	accuracy:0.9375000000	 [ 51200/ 69239]
# loss:0.1335529387	accuracy:0.9570312500	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.95726, Average loss:   0.137743
#
# * * * * * * * * * *
# Epoch 56
# loss:0.1279584169	accuracy:0.9687500000	 [ 12800/ 69239]
# loss:0.1271639764	accuracy:0.9570312500	 [ 25600/ 69239]
# loss:0.1261746287	accuracy:0.9453125000	 [ 38400/ 69239]
# loss:0.1672188193	accuracy:0.9414062500	 [ 51200/ 69239]
# loss:0.1328533292	accuracy:0.9570312500	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.95726, Average loss:   0.136835
#
# * * * * * * * * * *
# Epoch 57
# loss:0.1271899790	accuracy:0.9687500000	 [ 12800/ 69239]
# loss:0.1265024245	accuracy:0.9570312500	 [ 25600/ 69239]
# loss:0.1250540018	accuracy:0.9492187500	 [ 38400/ 69239]
# loss:0.1663327068	accuracy:0.9414062500	 [ 51200/ 69239]
# loss:0.1321326494	accuracy:0.9570312500	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.95726, Average loss:   0.135911
#
# * * * * * * * * * *
# Epoch 58
# loss:0.1263767034	accuracy:0.9687500000	 [ 12800/ 69239]
# loss:0.1257146895	accuracy:0.9570312500	 [ 25600/ 69239]
# loss:0.1238613054	accuracy:0.9492187500	 [ 38400/ 69239]
# loss:0.1651668847	accuracy:0.9414062500	 [ 51200/ 69239]
# loss:0.1312848330	accuracy:0.9570312500	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.95726, Average loss:   0.134890
#
# * * * * * * * * * *
# Epoch 59
# loss:0.1253606677	accuracy:0.9687500000	 [ 12800/ 69239]
# loss:0.1247829795	accuracy:0.9570312500	 [ 25600/ 69239]
# loss:0.1225678474	accuracy:0.9492187500	 [ 38400/ 69239]
# loss:0.1640813649	accuracy:0.9414062500	 [ 51200/ 69239]
# loss:0.1304088831	accuracy:0.9609375000	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.96154, Average loss:   0.133932
#
# * * * * * * * * * *
# Epoch 60
# loss:0.1243818253	accuracy:0.9687500000	 [ 12800/ 69239]
# loss:0.1239409968	accuracy:0.9570312500	 [ 25600/ 69239]
# loss:0.1213187724	accuracy:0.9492187500	 [ 38400/ 69239]
# loss:0.1629338861	accuracy:0.9414062500	 [ 51200/ 69239]
# loss:0.1296943277	accuracy:0.9609375000	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.96154, Average loss:   0.132970
#
# * * * * * * * * * *
# Epoch 61
# loss:0.1233299896	accuracy:0.9687500000	 [ 12800/ 69239]
# loss:0.1230498254	accuracy:0.9570312500	 [ 25600/ 69239]
# loss:0.1199314222	accuracy:0.9531250000	 [ 38400/ 69239]
# loss:0.1617613733	accuracy:0.9414062500	 [ 51200/ 69239]
# loss:0.1288687289	accuracy:0.9609375000	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.96154, Average loss:   0.131943
#
# * * * * * * * * * *
# Epoch 62
# loss:0.1222265884	accuracy:0.9687500000	 [ 12800/ 69239]
# loss:0.1222046018	accuracy:0.9570312500	 [ 25600/ 69239]
# loss:0.1187366992	accuracy:0.9531250000	 [ 38400/ 69239]
# loss:0.1602514982	accuracy:0.9414062500	 [ 51200/ 69239]
# loss:0.1282922328	accuracy:0.9609375000	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.96154, Average loss:   0.130803
#
# * * * * * * * * * *
# Epoch 63
# loss:0.1212555915	accuracy:0.9687500000	 [ 12800/ 69239]
# loss:0.1214004606	accuracy:0.9609375000	 [ 25600/ 69239]
# loss:0.1174312085	accuracy:0.9531250000	 [ 38400/ 69239]
# loss:0.1589411497	accuracy:0.9414062500	 [ 51200/ 69239]
# loss:0.1274136305	accuracy:0.9609375000	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.96154, Average loss:   0.129705
#
# * * * * * * * * * *
# Epoch 64
# loss:0.1202477142	accuracy:0.9687500000	 [ 12800/ 69239]
# loss:0.1204017401	accuracy:0.9609375000	 [ 25600/ 69239]
# loss:0.1160943359	accuracy:0.9570312500	 [ 38400/ 69239]
# loss:0.1577014625	accuracy:0.9453125000	 [ 51200/ 69239]
# loss:0.1267126799	accuracy:0.9609375000	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.96154, Average loss:   0.128673
#
# * * * * * * * * * *
# Epoch 65
# loss:0.1192817688	accuracy:0.9687500000	 [ 12800/ 69239]
# loss:0.1195084378	accuracy:0.9609375000	 [ 25600/ 69239]
# loss:0.1148616001	accuracy:0.9570312500	 [ 38400/ 69239]
# loss:0.1564214081	accuracy:0.9453125000	 [ 51200/ 69239]
# loss:0.1260038912	accuracy:0.9609375000	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.96154, Average loss:   0.127637
#
# * * * * * * * * * *
# Epoch 66
# loss:0.1183439493	accuracy:0.9687500000	 [ 12800/ 69239]
# loss:0.1186503023	accuracy:0.9609375000	 [ 25600/ 69239]
# loss:0.1134658605	accuracy:0.9570312500	 [ 38400/ 69239]
# loss:0.1551640928	accuracy:0.9453125000	 [ 51200/ 69239]
# loss:0.1252444685	accuracy:0.9609375000	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.96154, Average loss:   0.126562
#
# * * * * * * * * * *
# Epoch 67
# loss:0.1174250096	accuracy:0.9687500000	 [ 12800/ 69239]
# loss:0.1177371889	accuracy:0.9609375000	 [ 25600/ 69239]
# loss:0.1121056005	accuracy:0.9570312500	 [ 38400/ 69239]
# loss:0.1538900137	accuracy:0.9453125000	 [ 51200/ 69239]
# loss:0.1245039254	accuracy:0.9609375000	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.96154, Average loss:   0.125502
#
# * * * * * * * * * *
# Epoch 68
# loss:0.1163701117	accuracy:0.9687500000	 [ 12800/ 69239]
# loss:0.1167632267	accuracy:0.9609375000	 [ 25600/ 69239]
# loss:0.1106676310	accuracy:0.9570312500	 [ 38400/ 69239]
# loss:0.1526723355	accuracy:0.9453125000	 [ 51200/ 69239]
# loss:0.1237869114	accuracy:0.9648437500	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.96154, Average loss:   0.124416
#
# * * * * * * * * * *
# Epoch 69
# loss:0.1153905913	accuracy:0.9687500000	 [ 12800/ 69239]
# loss:0.1158014163	accuracy:0.9609375000	 [ 25600/ 69239]
# loss:0.1091901511	accuracy:0.9570312500	 [ 38400/ 69239]
# loss:0.1512915492	accuracy:0.9453125000	 [ 51200/ 69239]
# loss:0.1228952259	accuracy:0.9648437500	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.96154, Average loss:   0.123303
#
# * * * * * * * * * *
# Epoch 70
# loss:0.1142898649	accuracy:0.9687500000	 [ 12800/ 69239]
# loss:0.1147795543	accuracy:0.9609375000	 [ 25600/ 69239]
# loss:0.1075594723	accuracy:0.9570312500	 [ 38400/ 69239]
# loss:0.1498172283	accuracy:0.9453125000	 [ 51200/ 69239]
# loss:0.1221637279	accuracy:0.9648437500	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.96154, Average loss:   0.121970
#
# * * * * * * * * * *
# Epoch 71
# loss:0.1128699630	accuracy:0.9687500000	 [ 12800/ 69239]
# loss:0.1136770546	accuracy:0.9609375000	 [ 25600/ 69239]
# loss:0.1057873368	accuracy:0.9570312500	 [ 38400/ 69239]
# loss:0.1484498978	accuracy:0.9453125000	 [ 51200/ 69239]
# loss:0.1211141199	accuracy:0.9687500000	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.96154, Average loss:   0.120721
#
# * * * * * * * * * *
# Epoch 72
# loss:0.1118044481	accuracy:0.9687500000	 [ 12800/ 69239]
# loss:0.1126513407	accuracy:0.9648437500	 [ 25600/ 69239]
# loss:0.1043463796	accuracy:0.9570312500	 [ 38400/ 69239]
# loss:0.1470693946	accuracy:0.9453125000	 [ 51200/ 69239]
# loss:0.1203430519	accuracy:0.9687500000	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.96154, Average loss:   0.119475
#
# * * * * * * * * * *
# Epoch 73
# loss:0.1107202098	accuracy:0.9687500000	 [ 12800/ 69239]
# loss:0.1115314960	accuracy:0.9648437500	 [ 25600/ 69239]
# loss:0.1031493470	accuracy:0.9609375000	 [ 38400/ 69239]
# loss:0.1453607380	accuracy:0.9453125000	 [ 51200/ 69239]
# loss:0.1195342839	accuracy:0.9687500000	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.96154, Average loss:   0.118112
#
# * * * * * * * * * *
# Epoch 74
# loss:0.1093802825	accuracy:0.9687500000	 [ 12800/ 69239]
# loss:0.1103681475	accuracy:0.9648437500	 [ 25600/ 69239]
# loss:0.1018418372	accuracy:0.9609375000	 [ 38400/ 69239]
# loss:0.1437461376	accuracy:0.9492187500	 [ 51200/ 69239]
# loss:0.1184974909	accuracy:0.9687500000	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.96154, Average loss:   0.116889
#
# * * * * * * * * * *
# Epoch 75
# loss:0.1082515568	accuracy:0.9687500000	 [ 12800/ 69239]
# loss:0.1092534140	accuracy:0.9648437500	 [ 25600/ 69239]
# loss:0.1004723012	accuracy:0.9648437500	 [ 38400/ 69239]
# loss:0.1422591805	accuracy:0.9492187500	 [ 51200/ 69239]
# loss:0.1175209433	accuracy:0.9687500000	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.96154, Average loss:   0.115655
#
# * * * * * * * * * *
# Epoch 76
# loss:0.1070473194	accuracy:0.9687500000	 [ 12800/ 69239]
# loss:0.1080855131	accuracy:0.9648437500	 [ 25600/ 69239]
# loss:0.0991071463	accuracy:0.9687500000	 [ 38400/ 69239]
# loss:0.1407407671	accuracy:0.9492187500	 [ 51200/ 69239]
# loss:0.1165606081	accuracy:0.9687500000	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.96154, Average loss:   0.114366
#
# * * * * * * * * * *
# Epoch 77
# loss:0.1058034301	accuracy:0.9687500000	 [ 12800/ 69239]
# loss:0.1068460643	accuracy:0.9648437500	 [ 25600/ 69239]
# loss:0.0979062170	accuracy:0.9687500000	 [ 38400/ 69239]
# loss:0.1391905248	accuracy:0.9492187500	 [ 51200/ 69239]
# loss:0.1155125946	accuracy:0.9687500000	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.96154, Average loss:   0.113124
#
# * * * * * * * * * *
# Epoch 78
# loss:0.1045368388	accuracy:0.9687500000	 [ 12800/ 69239]
# loss:0.1056802049	accuracy:0.9609375000	 [ 25600/ 69239]
# loss:0.0967408866	accuracy:0.9687500000	 [ 38400/ 69239]
# loss:0.1377228647	accuracy:0.9492187500	 [ 51200/ 69239]
# loss:0.1144291013	accuracy:0.9687500000	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.96581, Average loss:   0.111861
#
# * * * * * * * * * *
# Epoch 79
# loss:0.1033580303	accuracy:0.9687500000	 [ 12800/ 69239]
# loss:0.1045025662	accuracy:0.9609375000	 [ 25600/ 69239]
# loss:0.0955939740	accuracy:0.9687500000	 [ 38400/ 69239]
# loss:0.1360532194	accuracy:0.9531250000	 [ 51200/ 69239]
# loss:0.1133995205	accuracy:0.9687500000	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.96581, Average loss:   0.110610
#
# * * * * * * * * * *
# Epoch 80
# loss:0.1020592153	accuracy:0.9687500000	 [ 12800/ 69239]
# loss:0.1032828689	accuracy:0.9609375000	 [ 25600/ 69239]
# loss:0.0944062844	accuracy:0.9726562500	 [ 38400/ 69239]
# loss:0.1345261037	accuracy:0.9531250000	 [ 51200/ 69239]
# loss:0.1123083457	accuracy:0.9687500000	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.96581, Average loss:   0.109344
#
# * * * * * * * * * *
# Epoch 81
# loss:0.1008394957	accuracy:0.9687500000	 [ 12800/ 69239]
# loss:0.1020909920	accuracy:0.9609375000	 [ 25600/ 69239]
# loss:0.0931640938	accuracy:0.9726562500	 [ 38400/ 69239]
# loss:0.1328644902	accuracy:0.9531250000	 [ 51200/ 69239]
# loss:0.1106374711	accuracy:0.9687500000	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.96581, Average loss:   0.107786
#
# * * * * * * * * * *
# Epoch 82
# loss:0.0994743258	accuracy:0.9687500000	 [ 12800/ 69239]
# loss:0.1003620028	accuracy:0.9648437500	 [ 25600/ 69239]
# loss:0.0917281955	accuracy:0.9765625000	 [ 38400/ 69239]
# loss:0.1308164597	accuracy:0.9531250000	 [ 51200/ 69239]
# loss:0.1097148955	accuracy:0.9687500000	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.96581, Average loss:   0.106345
#
# * * * * * * * * * *
# Epoch 83
# loss:0.0979393572	accuracy:0.9687500000	 [ 12800/ 69239]
# loss:0.0990568846	accuracy:0.9648437500	 [ 25600/ 69239]
# loss:0.0905499384	accuracy:0.9765625000	 [ 38400/ 69239]
# loss:0.1290771514	accuracy:0.9570312500	 [ 51200/ 69239]
# loss:0.1085851938	accuracy:0.9687500000	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.96581, Average loss:   0.104971
#
# * * * * * * * * * *
# Epoch 84
# loss:0.0965469182	accuracy:0.9687500000	 [ 12800/ 69239]
# loss:0.0977610946	accuracy:0.9648437500	 [ 25600/ 69239]
# loss:0.0893306807	accuracy:0.9765625000	 [ 38400/ 69239]
# loss:0.1274189651	accuracy:0.9570312500	 [ 51200/ 69239]
# loss:0.1074254662	accuracy:0.9687500000	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.96581, Average loss:   0.103609
#
# * * * * * * * * * *
# Epoch 85
# loss:0.0952241570	accuracy:0.9687500000	 [ 12800/ 69239]
# loss:0.0963805765	accuracy:0.9648437500	 [ 25600/ 69239]
# loss:0.0881658047	accuracy:0.9765625000	 [ 38400/ 69239]
# loss:0.1256235540	accuracy:0.9609375000	 [ 51200/ 69239]
# loss:0.1061855853	accuracy:0.9687500000	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.96581, Average loss:   0.102241
#
# * * * * * * * * * *
# Epoch 86
# loss:0.0939061046	accuracy:0.9687500000	 [ 12800/ 69239]
# loss:0.0950854123	accuracy:0.9648437500	 [ 25600/ 69239]
# loss:0.0870163515	accuracy:0.9765625000	 [ 38400/ 69239]
# loss:0.1238531917	accuracy:0.9609375000	 [ 51200/ 69239]
# loss:0.1050812602	accuracy:0.9687500000	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.96581, Average loss:   0.100812
#
# * * * * * * * * * *
# Epoch 87
# loss:0.0924336314	accuracy:0.9687500000	 [ 12800/ 69239]
# loss:0.0936039984	accuracy:0.9648437500	 [ 25600/ 69239]
# loss:0.0858466998	accuracy:0.9765625000	 [ 38400/ 69239]
# loss:0.1220657080	accuracy:0.9648437500	 [ 51200/ 69239]
# loss:0.1039601788	accuracy:0.9687500000	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.96581, Average loss:   0.099390
#
# * * * * * * * * * *
# Epoch 88
# loss:0.0910095125	accuracy:0.9687500000	 [ 12800/ 69239]
# loss:0.0922866613	accuracy:0.9648437500	 [ 25600/ 69239]
# loss:0.0846876875	accuracy:0.9765625000	 [ 38400/ 69239]
# loss:0.1202875227	accuracy:0.9648437500	 [ 51200/ 69239]
# loss:0.1026557237	accuracy:0.9726562500	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.96581, Average loss:   0.098009
#
# * * * * * * * * * *
# Epoch 89
# loss:0.0896330923	accuracy:0.9687500000	 [ 12800/ 69239]
# loss:0.0908833370	accuracy:0.9648437500	 [ 25600/ 69239]
# loss:0.0836311281	accuracy:0.9765625000	 [ 38400/ 69239]
# loss:0.1185380965	accuracy:0.9648437500	 [ 51200/ 69239]
# loss:0.1013532430	accuracy:0.9726562500	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.96581, Average loss:   0.096558
#
# * * * * * * * * * *
# Epoch 90
# loss:0.0881541520	accuracy:0.9726562500	 [ 12800/ 69239]
# loss:0.0895452201	accuracy:0.9687500000	 [ 25600/ 69239]
# loss:0.0824597180	accuracy:0.9765625000	 [ 38400/ 69239]
# loss:0.1167619079	accuracy:0.9648437500	 [ 51200/ 69239]
# loss:0.1000774875	accuracy:0.9726562500	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.96581, Average loss:   0.095150
#
# * * * * * * * * * *
# Epoch 91
# loss:0.0866882429	accuracy:0.9726562500	 [ 12800/ 69239]
# loss:0.0881120712	accuracy:0.9687500000	 [ 25600/ 69239]
# loss:0.0813495666	accuracy:0.9765625000	 [ 38400/ 69239]
# loss:0.1150143296	accuracy:0.9648437500	 [ 51200/ 69239]
# loss:0.0987479314	accuracy:0.9726562500	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.97009, Average loss:   0.093702
#
# * * * * * * * * * *
# Epoch 92
# loss:0.0852212608	accuracy:0.9726562500	 [ 12800/ 69239]
# loss:0.0867222697	accuracy:0.9687500000	 [ 25600/ 69239]
# loss:0.0802113563	accuracy:0.9765625000	 [ 38400/ 69239]
# loss:0.1132371575	accuracy:0.9687500000	 [ 51200/ 69239]
# loss:0.0974825919	accuracy:0.9726562500	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.97009, Average loss:   0.092266
#
# * * * * * * * * * *
# Epoch 93
# loss:0.0838115513	accuracy:0.9726562500	 [ 12800/ 69239]
# loss:0.0852967650	accuracy:0.9687500000	 [ 25600/ 69239]
# loss:0.0789592490	accuracy:0.9765625000	 [ 38400/ 69239]
# loss:0.1114826053	accuracy:0.9687500000	 [ 51200/ 69239]
# loss:0.0961957499	accuracy:0.9726562500	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.97009, Average loss:   0.090787
#
# * * * * * * * * * *
# Epoch 94
# loss:0.0822969973	accuracy:0.9726562500	 [ 12800/ 69239]
# loss:0.0837808251	accuracy:0.9687500000	 [ 25600/ 69239]
# loss:0.0778585896	accuracy:0.9765625000	 [ 38400/ 69239]
# loss:0.1092754602	accuracy:0.9687500000	 [ 51200/ 69239]
# loss:0.0948717594	accuracy:0.9726562500	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.97009, Average loss:   0.089201
#
# * * * * * * * * * *
# Epoch 95
# loss:0.0807092339	accuracy:0.9726562500	 [ 12800/ 69239]
# loss:0.0823104382	accuracy:0.9687500000	 [ 25600/ 69239]
# loss:0.0766244307	accuracy:0.9765625000	 [ 38400/ 69239]
# loss:0.1071843207	accuracy:0.9687500000	 [ 51200/ 69239]
# loss:0.0934168398	accuracy:0.9726562500	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.97009, Average loss:   0.087715
#
# * * * * * * * * * *
# Epoch 96
# loss:0.0790576041	accuracy:0.9726562500	 [ 12800/ 69239]
# loss:0.0807786286	accuracy:0.9687500000	 [ 25600/ 69239]
# loss:0.0752149373	accuracy:0.9765625000	 [ 38400/ 69239]
# loss:0.1051228568	accuracy:0.9687500000	 [ 51200/ 69239]
# loss:0.0916028023	accuracy:0.9726562500	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.97009, Average loss:   0.086149
#
# * * * * * * * * * *
# Epoch 97
# loss:0.0774717554	accuracy:0.9765625000	 [ 12800/ 69239]
# loss:0.0791785270	accuracy:0.9687500000	 [ 25600/ 69239]
# loss:0.0739800110	accuracy:0.9765625000	 [ 38400/ 69239]
# loss:0.1032237262	accuracy:0.9687500000	 [ 51200/ 69239]
# loss:0.0901308805	accuracy:0.9726562500	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.97009, Average loss:   0.084577
#
# * * * * * * * * * *
# Epoch 98
# loss:0.0758500472	accuracy:0.9765625000	 [ 12800/ 69239]
# loss:0.0776720047	accuracy:0.9726562500	 [ 25600/ 69239]
# loss:0.0729477704	accuracy:0.9765625000	 [ 38400/ 69239]
# loss:0.1008899361	accuracy:0.9726562500	 [ 51200/ 69239]
# loss:0.0890726447	accuracy:0.9726562500	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.97436, Average loss:   0.082508
#
# * * * * * * * * * *
# Epoch 99
# loss:0.0740777329	accuracy:0.9765625000	 [ 12800/ 69239]
# loss:0.0760384873	accuracy:0.9726562500	 [ 25600/ 69239]
# loss:0.0716050118	accuracy:0.9765625000	 [ 38400/ 69239]
# loss:0.0984504670	accuracy:0.9726562500	 [ 51200/ 69239]
# loss:0.0871293396	accuracy:0.9726562500	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.97436, Average loss:   0.080827
#
# * * * * * * * * * *
# Epoch 100
# loss:0.0726028383	accuracy:0.9765625000	 [ 12800/ 69239]
# loss:0.0745107085	accuracy:0.9726562500	 [ 25600/ 69239]
# loss:0.0705992356	accuracy:0.9765625000	 [ 38400/ 69239]
# loss:0.0964323133	accuracy:0.9726562500	 [ 51200/ 69239]
# loss:0.0855350122	accuracy:0.9726562500	 [ 64000/ 69239]
# Test error:
# 	Accuracy: 0.97863, Average loss:   0.079294
#
# Finished

# %% [markdown]
# ## Visualize Results

# %%
def scoring(prediction, actual, test=False):
    
    # convert from pytorch tensors to numpy arrays
    temp_pred = []
    temp_act = []
    
    for element in prediction:
        for el in element:
            if el[0]:
                temp_pred.append(el[0].detach().cpu().numpy())
            else:
                temp_pred.append(el.detach().cpu().numpy())
    
    
    for element in actual:
        try:
            for el in element:
                temp_act.append(el.detach().cpu().numpy())
        except:
            temp_act.append(element.detach().cpu().numpy())
            
    prediction = np.array(temp_pred).round().astype(int)
    actual = np.array(temp_act)
    
    
    # create a confusion matrix heatmap
    cm = confusion_matrix(prediction, actual)
    cm = pd.DataFrame(cm/np.sum(cm),
                      index=["Predicted False", "Predicted True"],
                      columns=["Actual False", "Actual True"])
    
    return prediction, actual, cm

# %%
p, a, cm = scoring2(training_result, trng_actual)

# %%
TP, TN = 0, 0
FP, FN = 0, 0
for i, j in list(zip(np.round(p), a)):
    if (i == j) and (i == 1):
        TP += 1
    elif (i == j) and (i == 0):
        TN += 1
    elif (i != j) and (i == 1):
        FP += 1
    elif (i != j) and (i == 0):
        FN += 1
print(TP, TN, FP, FN)
# Out:
# 4 249 0 3

# %%
plt.figure(figsize=(10,6))
sns.heatmap(cm, annot=True)
plt.show()

# %%
trng, _ = next(iter(training_data))

# %%
#writer.add_pr_curve('Precision Recall Curve', actual, predictions, 0)
writer.add_graph(model, trng)
writer.add_figure("Confusion Matrix", sns.heatmap(cm, annot=True).get_figure())

# %%
sns.heatmap(cm, annot=True)
# Out:
# <AxesSubplot:>

# %%
temp = []
for element in training_loss:
    for el in element:
        temp.append(el)
    
loss = np.array(temp)

# %%
range(len(loss))
# Out:
# range(0, 27100)

# %%
plt.figure(figsize=(10,6))
plt.plot(range(len(loss)), loss)
plt.title("Loss Plot")
plt.xlabel("Step")
plt.ylabel("Loss")
plt.show()
plt.savefig("lossplot.png")

# %%
for x in range(len(loss)):
    writer.add_scalar("Loss Plot", loss[x], x)

# %%
(len(data)-data.target.sum())/len(data)
# Out:
# 0.9452144814129588

# %% [markdown]
# # NOTES

# %% [markdown]
# #### 2022 Apr 11 @ 1920 PDT

# %% [markdown]
# 1) Model is trivially accurate. 94.5% of the data are negative. This imbalance needs to be addressed for the frenchC2C dataset.
#
# 2) Implement the tensorboard summarywriter upstream to capture data en route.

# %%
writer.close()

# %% [markdown]
# #### Display on Tensorboard

# %%
# %load_ext tensorboard

# %%
# !tensorboard --logdir=frenchC2Cdata
# Out:
# TensorFlow installation not found - running with reduced feature set.
#
# NOTE: Using experimental fast data loading logic. To disable, pass
#     "--load_fast=false" and report issues on GitHub. More details:
#     https://github.com/tensorflow/tensorboard/issues/4784
#
# Serving TensorBoard on localhost; to expose to the network, use a proxy or pass --bind_all
# TensorBoard 2.8.0 at http://localhost:6006/ (Press CTRL+C to quit)
# ^C

# %% [markdown]
# ##### Note:
# * Click the link localhost:6006 to open Tensorboard.
# * Tensorboard must be terminated manually by closing the window and stopping the kernel for the executing cell
